# %%
# !pip install rdkit meeko vina biopython gemmi openbabel

# %%
# !git clone https://github.com/daniellaeme/rutin3d.git
# Out:
# fatal: destination path 'rutin3d' already exists and is not an empty directory.

# %%
# !ls -la
# Out:
# total 24
# drwxr-xr-x 1 root root 4096 Jul 29 12:26 .
# drwxr-xr-x 1 root root 4096 Jul 29 12:21 ..
# drwxr-xr-x 4 root root 4096 Jun  4 13:32 .config
# drwxr-xr-x 4 root root 4096 Jul 29 12:26 pycharm-libs
# drwxr-xr-x 7 root root 4096 Jul 29 12:26 rutin3d
# drwxr-xr-x 1 root root 4096 Jun  4 13:32 sample_data

# %%
# %cd /content/rutin3d
# Out:
# /content/rutin3d

# %%
# !wget https://github.com/ccsb-scripps/AutoDock-Vina/releases/download/v1.2.5/vina_1.2.5_linux_x86_64
# !mv vina_1.2.5_linux_x86_64 vina
# !chmod +x vina
# Out:
# --2026-07-29 12:38:10--  https://github.com/ccsb-scripps/AutoDock-Vina/releases/download/v1.2.5/vina_1.2.5_linux_x86_64
# Resolving github.com (github.com)... 20.27.177.113
# Connecting to github.com (github.com)|20.27.177.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
import os
import platform
if platform.system() == 'Windows':
    vina_executable = '.\\vina.exe'
else:
    vina_executable = './vina'

# %%
# !python main.py
# Out:
# /nPREPARING RECEPTOR (mPGES-1)
# DEBUG: Number of chains found in model: 1
# DEBUG: Total residues found: 240
# DEBUG: Unique residue names: {'MET', 'PHE', 'THR', 'SER', 'PLM', 'CYS', 'TRP', 'HIS', 'ARG', 'HOH', 'BOG', 'ALA', 'TYR', 'GLU', 'GLN', 'VAL', 'GLY', 'ASN', 'LYS', 'ASP', 'PRO', 'GSH', 'ILE', 'LEU'}
#
# [1/5]
# PDB file successfully parsed
#
# [2/5]
# Located target ligand "GSH" inside Chain "A"
#
# [3/5]
# Calculated active site Centroid based on native GSH:
# 8.11815071105957 -8.941800117492676 -8.353998184204102
#
# [4/5]
# Operating in Monomer Mode (only 1 chain found: Chain "A"). Skipping interfacial partner detection.
#
# [5/5]
# Monomer (Chain A) successfully isolated and cleaned!
# Saved cleaned structural coordinates to: "./data/processed/receptor_prep/receptor_clean.pdb"
#
# Starting Receptor PDBQT Preparation using OpenBabel
# ...
# *** Open Babel Warning  in PerceiveBondOrders
# ...
