# %%
# !pip install rdkit meeko vina biopython gemmi openbabel protobuf

# %%
# !wget https://github.com/ccsb-scripps/AutoDock-Vina/releases/download/v1.2.5/vina_1.2.5_linux_x86_64
# !mv vina_1.2.5_linux_x86_64 vina
# !chmod +x vina
# Out:
# --2026-07-29 14:04:48--  https://github.com/ccsb-scripps/AutoDock-Vina/releases/download/v1.2.5/vina_1.2.5_linux_x86_64
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# %cd /content
# !rm -rf rutin3d
# !git clone https://github.com/daniellaeme/rutin3d.git
# Out:
# /content
# Cloning into 'rutin3d'...
# remote: Enumerating objects: 199, done.
# remote: Counting objects: 100% (199/199), done.
# remote: Compressing objects: 100% (124/124), done.
# remote: Total 199 (delta 98), reused 166 (delta 68), pack-reused 0 (from 0)
# Receiving objects: 100% (199/199), 1.96 MiB | 10.56 MiB/s, done.
# Resolving deltas: 100% (98/98), done.

# %%
# %cd /content/rutin3d
# Out:
# /content/rutin3d

# %%
# !python main.py
# Out:
# /nPREPARING RECEPTOR (mPGES-1)
# DEBUG: Number of chains found in model: 1
# DEBUG: Total residues found: 240
# DEBUG: Unique residue names: {'GLY', 'PRO', 'ALA', 'ILE', 'CYS', 'GLN', 'PHE', 'LYS', 'HOH', 'TYR', 'ASN', 'ARG', 'TRP', 'ASP', 'MET', 'PLM', 'BOG', 'HIS', 'SER', 'GSH', 'LEU', 'GLU', 'VAL', 'THR'}
#
# [1/5]
# PDB file successfully parsed
#
# [2/5]
# Located target ligand "GSH" inside Chain "A"
#
# [3/5]
# Calculated active site Centroid based on native GSH:
# 8.11815071105957 -8.941800117492676 -8.353998184204102
#
# [4/5]
# Operating in Monomer Mode (only 1 chain found: Chain "A"). Skipping interfacial partner detection.
#
# [5/5]
# Monomer (Chain A) successfully isolated and cleaned!
# Saved cleaned structural coordinates to: "./data/processed/receptor_prep/receptor_clean.pdb"
#
# Starting Receptor PDBQT Preparation using OpenBabel
# ...
# *** Open Babel Warning  in PerceiveBondOrders
# ...

# %%
from google.colab import files
# !zip -r -q rutin3d_completed_data.zip results/ data/processed/
files.download('rutin3d_completed_data.zip')
