# %%
# !pip install rdkit meeko vina biopython gemmi openbabel
# Out:
# Collecting rdkit
#   Downloading rdkit-2026.3.4-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Collecting meeko
#   Downloading meeko-0.7.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting vina
#   Downloading vina-1.2.7-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.1 kB)
# Collecting biopython
#   Downloading biopython-1.87-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (13 kB)
# Collecting gemmi
#   Downloading gemmi-0.7.5-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (2.3 kB)
# Collecting openbabel
#   Downloading openbabel-3.2.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (4.0 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from rdkit) (2.0.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from rdkit) (11.3.0)
# Requirement already satisfied: setuptools>=50.3 in /usr/local/lib/python3.12/dist-packages (from vina) (75.2.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.12/dist-packages (from vina) (0.47.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from vina) (26.2)
# Downloading rdkit-2026.3.4-cp312-cp312-manylinux_2_28_x86_64.whl (37.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.4/37.4 MB 41.2 MB/s eta 0:00:00:00:0100:01
# Downloading meeko-0.7.1-py3-none-any.whl (293 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.0/294.0 kB 17.1 MB/s eta 0:00:00
# Downloading vina-1.2.7-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 78.4 MB/s eta 0:00:00:00:0100:01
# Downloading biopython-1.87-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 70.5 MB/s eta 0:00:00:00:01
# Downloading gemmi-0.7.5-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 74.8 MB/s eta 0:00:00:00:01
# Downloading openbabel-3.2.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (12.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.6/12.6 MB 68.2 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: meeko, rdkit, openbabel, gemmi, biopython, vina
# Successfully installed biopython-1.87 gemmi-0.7.5 meeko-0.7.1 openbabel-3.2.1 rdkit-2026.3.4 vina-1.2.7

# %%
import os
import platform
if platform.system() == 'Windows':
    vina_executable = '.\\vina.exe'
else:
    vina_executable = './vina'

# %%
# !git clone https://github.com/daniellaeme/rutin3d.git
# Out:
# Cloning into 'rutin3d'...
# remote: Enumerating objects: 179, done.
# remote: Counting objects: 100% (179/179), done.
# remote: Compressing objects: 100% (112/112), done.
# remote: Total 179 (delta 83), reused 153 (delta 60), pack-reused 0 (from 0)
# Receiving objects: 100% (179/179), 1.95 MiB | 17.69 MiB/s, done.
# Resolving deltas: 100% (83/83), done.

# %%
# !ls -la
# Out:
# total 1288
# drwxr-xr-x 8 root root    4096 Jul 29 11:48 .
# drwxr-xr-x 1 root root    4096 Jul 29 11:44 ..
# drwxr-xr-x 4 root root    4096 Jul 29 11:44 data
# drwxr-xr-x 8 root root    4096 Jul 29 11:44 .git
# -rw-r--r-- 1 root root     322 Jul 29 11:44 .gitignore
# -rw-r--r-- 1 root root    1069 Jul 29 11:44 LICENSE
# -rw-r--r-- 1 root root    8226 Jul 29 11:44 main.py
# drwxr-xr-x 2 root root    4096 Jul 29 11:44 notes
# -rw-r--r-- 1 root root    4139 Jul 29 11:44 README.md
# -rw-r--r-- 1 root root   10352 Jul 29 11:44 requirements.txt
# drwxr-xr-x 2 root root    4096 Jul 29 11:44 results
# -rw-r--r-- 1 root root    6907 Jul 29 11:44 run_pipeline.ipynb
# drwxr-xr-x 7 root root    4096 Jul 29 11:48 rutin3d
# drwxr-xr-x 3 root root    4096 Jul 29 11:45 scripts
# -rw-r--r-- 1 root root 1233920 Jul 29 11:44 vina.exe

# %%
# %cd /content/rutin3d
# Out:
# /content/rutin3d

# %%
# !python main.py
# Out:
# /nPREPARING RECEPTOR (mPGES-1)
# DEBUG: Number of chains found in model: 1
# DEBUG: Total residues found: 240
# DEBUG: Unique residue names: {'LEU', 'TYR', 'GSH', 'VAL', 'CYS', 'HIS', 'BOG', 'GLN', 'TRP', 'PLM', 'THR', 'PRO', 'HOH', 'LYS', 'MET', 'GLU', 'ARG', 'ILE', 'ASP', 'GLY', 'SER', 'ASN', 'ALA', 'PHE'}
#
# [1/5]
# PDB file successfully parsed
#
# [2/5]
# Located target ligand "GSH" inside Chain "A"
#
# [3/5]
# Calculated active site Centroid based on native GSH:
# 8.11815071105957 -8.941800117492676 -8.353998184204102
#
# [4/5]
# Operating in Monomer Mode (only 1 chain found: Chain "A"). Skipping interfacial partner detection.
#
# [5/5]
# Monomer (Chain A) successfully isolated and cleaned!
# Saved cleaned structural coordinates to: "./data/processed/receptor_prep/receptor_clean.pdb"
#
# Starting Receptor PDBQT Preparation using OpenBabel
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ./data/processed/receptor_prep/receptor_clean.pdb)
#
# [1/2] Polar hydrogens added to receptor side-chains.
# [2/2] Prepared receptor stripped of invalid tags and saved to: ./data/processed/docking/receptor_prepared.pdbqt
#
# Successfully prepared receptor!
# Receptor File: ./data/processed/receptor_prep/receptor_clean.pdb
# AutoDock Vina Grid Parameters:
#   --center_x 8.118
#   --center_y -8.942
#   --center_z -8.354
#   --size_x 22.0 --size_y 22.0 --size_z 22.0
# Checkpoint file found. Loading prior docking results...
# Caffeic acid already processed. Score: -6.367
# Skipping...
# p-Coumaric acid already processed. Score: -6.461
# Skipping...
# Ferulic acid already processed. Score: -6.514
# Skipping...
# Rutin already processed. Score: -7.429
# Skipping...
# Apigenin-7-glucoside already processed. Score: -7.726
# Skipping...
# Quercetin already processed. Score: -7.445
# Skipping...
# Kaempferol already processed. Score: -7.163
# Skipping...
# Cyclododecyne already processed. Score: -3.779
# Skipping...
# Hexadecanoic acid already processed. Score: -6.066
# Skipping...
#
# Processing Compound: FRIEDELIN
#
# Pipeline failed for Friedelin: Cannot set unknown attribute 'maxAttempts'
#
# Processing Compound: BETA-SITOSTEROL
#
# Pipeline failed for Beta-Sitosterol: Cannot set unknown attribute 'maxAttempts'
# Ibuprofen already processed. Score: -7.294
# Skipping...
# Diclofenac already processed. Score: -6.277
# Skipping...
# Aspirin already processed. Score: -6.15
# Skipping...
# Celecoxib already processed. Score: -8.234
# Skipping...
#
# BATCH DOCKING RESULTS SUMMARY
#
# Celecoxib            : -8.23 kcal/mol
# Apigenin-7-glucoside : -7.73 kcal/mol
# Quercetin            : -7.45 kcal/mol
# Rutin                : -7.43 kcal/mol
# Ibuprofen            : -7.29 kcal/mol
# Kaempferol           : -7.16 kcal/mol
# Ferulic acid         : -6.51 kcal/mol
# p-Coumaric acid      : -6.46 kcal/mol
# Caffeic acid         : -6.37 kcal/mol
# Diclofenac           : -6.28 kcal/mol
# Aspirin              : -6.15 kcal/mol
# Hexadecanoic acid    : -6.07 kcal/mol
# Cyclododecyne        : -3.78 kcal/mol
# Friedelin            : FAILED
# Beta-Sitosterol      : FAILED
# Master results table automatically updated at: ./results/master_docking_scores.csv
